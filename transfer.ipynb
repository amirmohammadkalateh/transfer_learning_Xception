# %% [markdown]
# <a href="https://colab.research.google.com/github/amirmohammadkalateh/transfer_learning_Xception/blob/main/transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
from tensorflow import keras

# %%
xception_base = keras.applications.Xception(include_top = False)
# Out:
# ...
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#global average pooling
ga_layer = keras.layers.GlobalAveragePooling2D()(xception_base.output)
output = keras.layers.Dense(10 , activation="softmax")(ga_layer)
model_1 = keras.Model(inputs =xception_base.input , outputs = output)

# %%
for layer in xception_base.layers :
  layer.trainable = False

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = "adam" ,
              metrics = (["accuracy"]) )

# %%
x_train = x_train[:1000 , ]
y_train = y_train[:1000 , ]

# %%
# and model.fit
